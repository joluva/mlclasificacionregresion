# %% [markdown]
# ### Ejercicio 2 MOD4

# %%
#Importar librerías

from sklearn.datasets import fetch_california_housing

from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_squared_error, explained_variance_score

import numpy as np

# %%
#Cargar dataset

cal_housing = fetch_california_housing()

# %%
#Seleccionar variables

X = cal_housing.data[:, [6]] # seleccionando solo la columna de ingreso medio

y = cal_housing.target

# %%
# Aplicar el modelo de regresión linear
reg = DecisionTreeRegressor(random_state=0).fit(X, y)
y_pred = reg.predict(X)
mse= mean_squared_error(y, y_pred)
evs = explained_variance_score(y, y_pred)

print("Mean Squared Error: {:.2f}".format(mse))
print("Explained Variance Score: {:.2f}".format(evs))
# Out:
# Mean Squared Error: 0.96
# Explained Variance Score: 0.28
